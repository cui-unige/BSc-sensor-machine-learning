# %% [markdown]
# # Test d'utilisation de Jupyter et influxdb
#
# First I will try import a data base with influxdb.

# %%
from influxdb import InfluxDBClient


client = InfluxDBClient("129.194.71.136", 8086 , 'root', 'root', 'example')

#client.create_database('example')

json_body = [
    {
        "measurement": "brushEvents",
        "tags": {
            "user": "Carol",
            "brushId": "6c89f539-71c6-490d-a28d-6c5d84c0ee2f"
        },
        "time": "2018-03-28T8:01:00Z",
        "fields": {
            "duration": 127
        }
    },
    {
        "measurement": "brushEvents",
        "tags": {
            "user": "Carol",
            "brushId": "6c89f539-71c6-490d-a28d-6c5d84c0ee2f"
        },
        "time": "2018-03-29T8:04:00Z",
        "fields": {
            "duration": 132
        }
    },
    {
        "measurement": "brushEvents",
        "tags": {
            "user": "Carol",
            "brushId": "6c89f539-71c6-490d-a28d-6c5d84c0ee2f"
        },
        "time": "2018-03-30T8:02:00Z",
        "fields": {
            "duration": 129
        }
    }
]

client.write_points(json_body)

query_body = """
SELECT mean("moisture-percent") AS "mean_moisture-percent" 
FROM "ceres"."autogen"."chirp-left" 
WHERE time > now() - 100h
GROUP BY time(1m)
"""
#GROUP BY time(5m)
result = client.query(query_body)
#result = client.query('SELECT mean("humidity") AS "mean_humidity" FROM "ceres"."autogen"."Meteo" WHERE time > now() - 1h')
print("Result: {0}".format(result))

print("FINISH OK")
# Out:
# Result: ResultSet({'(u'chirp-left', None)': [{u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:00:00Z'}, {u'mean_moisture-percent': 22.7, u'time': u'2019-03-29T18:01:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:02:00Z'}, {u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:03:00Z'}, {u'mean_moisture-percent': 22.7, u'time': u'2019-03-29T18:04:00Z'}, {u'mean_moisture-percent': 22.45, u'time': u'2019-03-29T18:05:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:06:00Z'}, {u'mean_moisture-percent': 22.4, u'time': u'2019-03-29T18:07:00Z'}, {u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:08:00Z'}, {u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:09:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:10:00Z'}, {u'mean_moisture-percent': 22.75, u'time': u'2019-03-29T18:11:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:12:00Z'}, {u'mean_moisture-percent': 22.4, u'time': u'2019-03-29T18:13:00Z'}, {u'mean_moisture-percent': 22.6, u'time': u'2019-03-29T18:14:00Z'}, {u'mean_moisture-percent': 22.6, u'time': u'2019-03-29T18:15:00Z'}, {u'mean_moisture-percent': 22.2, u'time': u'2019-03-29T18:16:00Z'}, {u'mean_moisture-percent': 22.5, u'time': u'2019-03-29T18:17:00Z'}, {u'mean_moisture-percent': 22.8, u'time': u'2019-03-29T18:18:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:19:00Z'}, {u'mean_moisture-percent': 22.4, u'time': u'2019-03-29T18:20:00Z'}, {u'mean_moisture-percent': 22.7, u'time': u'2019-03-29T18:21:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:22:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:23:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:24:00Z'}, {u'mean_moisture-percent': 22.799999999999997, u'time': u'2019-03-29T18:25:00Z'}, {u'mean_moisture-percent': 22.45, u'time': u'2019-03-29T18:26:00Z'}, {u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:27:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:28:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:29:00Z'}, {u'mean_moisture-percent': 22.799999999999997, u'time': u'2019-03-29T18:30:00Z'}, {u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:31:00Z'}, {u'mean_moisture-percent': 22.35, u'time': u'2019-03-29T18:32:00Z'}, {u'mean_moisture-percent': 22.9, u'time': u'2019-03-29T18:33:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:34:00Z'}, {u'mean_moisture-percent': 22.5, u'time': u'2019-03-29T18:35:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:36:00Z'}, {u'mean_moisture-percent': 22.799999999999997, u'time': u'2019-03-29T18:37:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:38:00Z'}, {u'mean_moisture-percent': 22.4, u'time': u'2019-03-29T18:39:00Z'}, {u'mean_moisture-percent': 22.5, u'time': u'2019-03-29T18:40:00Z'}, {u'mean_moisture-percent': 22.7, u'time': u'2019-03-29T18:41:00Z'}, {u'mean_moisture-percent': 22.6, u'time': u'2019-03-29T18:42:00Z'}, {u'mean_moisture-percent': 22.5, u'time': u'2019-03-29T18:43:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:44:00Z'}, {u'mean_moisture-percent': 22.65, u'time': u'2019-03-29T18:45:00Z'}, {u'mean_moisture-percent': 22.6, u'time': u'2019-03-29T18:46:00Z'}, {u'mean_moisture-percent': 22.299999999999997, u'time': u'2019-03-29T18:47:00Z'}, {u'mean_moisture-percent': 22.549999999999997, u'time': u'2019-03-29T18:48:00Z'}, {u'mean_moisture-percent': 22.7, u'time': u'2019-03-29T18:49:00Z'}, {u'mean_moisture-percent': 22.2, u'time': u'2019-03-29T18:50:00Z'}, {u'mean_moisture-percent': 22.799999999999997, u'time': u'2019-03-29T18:51:00Z'}, {u'mean_moisture-percent': 22.299999999999997, u'time': u'2019-03-29T18:52:00Z'}, {u'mean_moisture-percent': 22.7, u'time': u'2019-03-29T18:53:00Z'}, {u'mean_moisture-percent': 22.6, u'time': u'2019-03-29T1 ...
# FINISH OK

# %% [markdown]
# # Afficher le résultat
#
# A l'aide d'une query et

# %%
query_body = """
SELECT mean("moisture-percent") AS "mean_moisture-percent" 
FROM "demeter"."autogen"."chirp-left" 
WHERE time > now() - 100h
GROUP BY time(5m)
"""
result = client.query(query_body)
#print("Result: {0}".format(result))
#client.query('SELECT "duration" FROM "example"."autogen"."brushEvents" WHERE time > now() - 4d GROUP BY "user"')

from matplotlib import pyplot

#result.raw
points = list(result.get_points())
print(points[2])
pyplot.plot(points)
#points = results.get_points(tags={'user':'Carol'})
#for point in points:
 #   print("Time: %s, Duration: %i", point['time'], point['mean_moisture-percent'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-80fbf286157c> in <module>()
#       9 #client.query('SELECT "duration" FROM "example"."autogen"."brushEvents" WHERE time > now() - 4d GROUP BY "user"')
#      10
# ---> 11 from matplotlib import pyplot
#      12
#      13 #result.raw
#
# ImportError: No module named matplotlib

# %%
import argparse
import pandas as pd

from influxdb import DataFrameClient


def main(host='129.194.71.136', port=8086):
    """Instantiate the connection to the InfluxDB client."""
    user = 'root'
    password = 'root'
    dbname = 'demo'
    protocol = 'json'

    client = DataFrameClient(host, port, user, password, dbname)

    print("Create pandas DataFrame")
    df = pd.DataFrame(data=list(range(30)),
                      index=pd.date_range(start='2014-11-16',
                                          periods=30, freq='H'), columns=['0'])

    print("Create database: " + dbname)
    client.create_database(dbname)

    print("Write DataFrame")
    client.write_points(df, 'demo', protocol=protocol)

    print("Write DataFrame with Tags")
    client.write_points(df, 'demo',
                        {'k1': 'v1', 'k2': 'v2'}, protocol=protocol)

    print("Read DataFrame")
    client.query("select * from demo")

    print("Delete database: " + dbname)
    client.drop_database(dbname)


def parse_args():
    """Parse the args from main."""
    parser = argparse.ArgumentParser(
        description='example code to play with InfluxDB')
    parser.add_argument('--host', type=str, required=False,
                        default='localhost',
                        help='hostname of InfluxDB http API')
    parser.add_argument('--port', type=int, required=False, default=8086,
                        help='port of InfluxDB http API')
    return parser.parse_args()


if __name__ == '__main__':
    args = parse_args()
main(host=args.host, port=args.port)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-4a616b9f40f2> in <module>()
#       1 import argparse
# ----> 2 import pandas as pd
#       3
#       4 from influxdb import DataFrameClient
#       5
#
# ImportError: No module named pandas
